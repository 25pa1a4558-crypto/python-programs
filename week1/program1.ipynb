# %% [markdown]
# <a href="https://colab.research.google.com/github/25pa1a4558-crypto/python-programs/blob/main/week1/program1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("my self santhosh")
# Out:
# my self santhosh

# %%
x=int(input("enter value of x:"))
y=int(input("enter value of y:"))
print("sum of x,y is", x+y)
print("sub of x,y is",x-y)
print("mul of x,y is", x*y)
print("div of x,y is",x/y)
print("mod of x,y is",x%y)
print("floor div of x,y is",x//y)
# Out:
# enter value of x:10
# enter value of y:2
# sum of x,y is 12
# sub of x,y is 8
# mul of x,y is 20
# div of x,y is 5.0
# mod of x,y is 0
# floor div of x,y is 5
